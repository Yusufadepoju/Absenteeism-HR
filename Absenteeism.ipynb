# %%
import pandas as pd
import seaborn as sns

# %%
file = pd.read_csv('C:/Users/Yusuf/Desktop/Portfolio Project/MFGEmployees4.csv')
data = pd.DataFrame(file)
data.head(2)
# Out:
#    EmployeeNumber    Surname GivenName Gender       City JobTitle  \
# 0               1  Gutierrez     Molly      F    Burnaby    Baker
# 1               2   Hardwick   Stephen      M  Courtenay    Baker
#
#   DepartmentName StoreLocation Division        Age  LengthService  \
# 0         Bakery       Burnaby   Stores  32.028816       6.018478
# 1         Bakery       Nanaimo   Stores  40.320902       5.532445
#
#    AbsentHours BusinessUnit
# 0    36.577306       Stores
# 1    30.165072       Stores

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8336 entries, 0 to 8335
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   EmployeeNumber  8336 non-null   int64
#  1   Surname         8336 non-null   object
#  2   GivenName       8336 non-null   object
#  3   Gender          8336 non-null   object
#  4   City            8336 non-null   object
#  5   JobTitle        8336 non-null   object
#  6   DepartmentName  8336 non-null   object
#  7   StoreLocation   8336 non-null   object
#  8   Division        8336 non-null   object
#  9   Age             8336 non-null   float64
#  10  LengthService   8336 non-null   float64
#  11  AbsentHours     8336 non-null   float64
#  12  BusinessUnit    8336 non-null   object
# dtypes: float64(3), int64(1), object(9)
# memory usage: 846.8+ KB

# %%
data.describe()
# Out:
#        EmployeeNumber          Age  LengthService  AbsentHours
# count     8336.000000  8336.000000    8336.000000  8336.000000
# mean      4168.500000    42.007086       4.782910    61.283978
# std       2406.540255     9.939798       2.462990    49.038365
# min          1.000000     3.504743       0.012098     0.000000
# 25%       2084.750000    35.298748       3.575892    19.127590
# 50%       4168.500000    42.114924       4.600248    56.005808
# 75%       6252.250000    48.666943       5.623922    94.284692
# max       8336.000000    77.938003      43.735239   272.530123

# %%
data.isnull().sum().sum()
# Out:
# 0

# %%
#Average Absent hours

round(data.AbsentHours.mean(), 2)
# Out:
# 61.28

# %%
data.head(3)
# Out:
#    EmployeeNumber    Surname GivenName Gender       City JobTitle  \
# 0               1  Gutierrez     Molly      F    Burnaby    Baker
# 1               2   Hardwick   Stephen      M  Courtenay    Baker
# 2               3    Delgado   Chester      M   Richmond    Baker
#
#   DepartmentName StoreLocation Division        Age  LengthService  \
# 0         Bakery       Burnaby   Stores  32.028816       6.018478
# 1         Bakery       Nanaimo   Stores  40.320902       5.532445
# 2         Bakery      Richmond   Stores  48.822047       4.389973
#
#    AbsentHours BusinessUnit
# 0    36.577306       Stores
# 1    30.165072       Stores
# 2    83.807798       Stores

# %%
from matplotlib import pyplot as plt
Department.plot(kind='bar', figsize=(14, 8))
plt.xlabel('Department')
plt.ylabel('Avg. Absent Hours')
print(Department.idxmax(),":", Department.max())
print(Department.idxmin(),":",  Department.min())
# Out:
# Stores : 61.59
# FinanceAndAccounting : 39.98

# %%
Store_Location = data.groupby('StoreLocation')['AbsentHours'].mean()

# %%
from matplotlib import pyplot as plt
Store_Location.plot(kind='bar', figsize=(14, 8))
plt.xlabel('Store Location')
plt.ylabel('Avg. Absent Hours')
# Out:
# Text(0, 0.5, 'Avg. Absent Hours')

# %%
Gender = data.groupby('Gender')['AbsentHours'].mean()
from matplotlib import pyplot as plt
Gender.plot(kind='bar', figsize=(14, 8))
plt.xlabel('Gender')
plt.ylabel('Avg. Absent Hours')
Gender
# Out:
# Gender
# F    66.688349
# M    56.002666
# Name: AbsentHours, dtype: float64

# %%
City = data.groupby('City')['AbsentHours'].mean()
from matplotlib import pyplot as plt
City.plot(kind='barh', figsize=(20, 40))
plt.xlabel('City')
plt.ylabel('Avg. Absent Hours')
print(City.idxmax())
print(City.idxmin())
# Out:
# Wynndel
# Sandspit

# %%
Job_Title = data.groupby('JobTitle')['AbsentHours'].mean()
from matplotlib import pyplot as plt
Job_Title.plot(kind='bar', figsize=(14, 6))
plt.xlabel('Job Title')
plt.ylabel('Avg. Absent Hours')
# Out:
# Text(0, 0.5, 'Avg. Absent Hours')

# %%
Division = data.groupby('Division')['AbsentHours'].mean()
from matplotlib import pyplot as plt
Division.plot(kind='bar', figsize=(14, 6))
plt.xlabel('Division')
plt.ylabel('Avg. Absent Hours')
# Out:
# Text(0, 0.5, 'Avg. Absent Hours')

# %%
Division = data.groupby('Age')['AbsentHours'].mean()
from matplotlib import pyplot as plt
plt.scatter(data.Age, data.AbsentHours)
plt.xlabel('Age')
plt.ylabel('Avg. Absent Hours')
# Out:
# Text(0, 0.5, 'Avg. Absent Hours')

# %% [markdown]
# Conclusion
# - The average absent hours of all employees is 61.28 hrs
# - There is diffrence in number of absent hours in each department, store location, gender, city,  job title, division.
#    - Stores dept has the highest number of absent hours.
#    - Finance and Accounting dept has the Lowest number of absent hours.
# - There is increase in numbers absent hours as there is increase in increase in age which implies that staff of older age tends to be more absent than younger ones.
# - The hours of female absentees are 19% higher than their male colleages.

# %%
data.head(3)
# Out:
#    EmployeeNumber    Surname GivenName Gender       City JobTitle  \
# 0               1  Gutierrez     Molly      F    Burnaby    Baker
# 1               2   Hardwick   Stephen      M  Courtenay    Baker
# 2               3    Delgado   Chester      M   Richmond    Baker
#
#   DepartmentName StoreLocation Division        Age  LengthService  \
# 0         Bakery       Burnaby   Stores  32.028816       6.018478
# 1         Bakery       Nanaimo   Stores  40.320902       5.532445
# 2         Bakery      Richmond   Stores  48.822047       4.389973
#
#    AbsentHours BusinessUnit
# 0    36.577306       Stores
# 1    30.165072       Stores
# 2    83.807798       Stores

# %%
colormap = plt.cm.RdBu
plt.figure(figsize=(15,15))
plt.title('Pearson Correlation of Features', y=1.0, size=10)
sns.heatmap(data.corr(),linewidths=0.2,vmax=1.0, 
            square=True, cmap=colormap, linecolor='white', annot=True)
# Out:
# <AxesSubplot:title={'center':'Pearson Correlation of Features'}>

# %%
sns.distplot(data.Age)
# Out:
# D:\New folder\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
sns.distplot(data.LengthService)
# Out:
# D:\New folder\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='LengthService', ylabel='Density'>

# %%
plt.figure(figsize=(15,9))
plt.hist(data.AbsentHours)
# Out:
# (array([2482., 1598., 1576., 1250.,  788.,  378.,  168.,   61.,   30.,
#            5.]),
#  array([  0.        ,  27.25301234,  54.50602468,  81.75903702,
#         109.01204936, 136.2650617 , 163.51807404, 190.77108638,
#         218.02409872, 245.27711106, 272.5301234 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.figure(figsize=(15,9))
plt.hist(data.StoreLocation)
#plt.xtick(90)
# Out:
# (array([2031., 2828.,  765.,  571.,  790.,  624.,  320.,  253.,  100.,
#           54.]),
#  array([ 0. ,  3.9,  7.8, 11.7, 15.6, 19.5, 23.4, 27.3, 31.2, 35.1, 39. ]),
#  <BarContainer object of 10 artists>)

# %%
def transform(feild, new_feild):
    dicts = dict(zip(feild.unique(), range(len(feild.unique()))))
    print(dicts)
    data[new_feild] = feild.map(dicts).astype(int)
    
    
transform(data.Gender, 'new_Gender')
print()
transform(data.City, 'new_City')
print()
transform(data.JobTitle, 'new_Title')
print()
transform(data.DepartmentName, 'new_Dept')
print()
transform(data.StoreLocation, 'new_StoreLoc')
print()
transform(data.Division, 'new_Division')
# Out:
# {'F': 0, 'M': 1}
#
# ...

# %%
data.head(2)
# Out:
#    EmployeeNumber    Surname GivenName Gender       City JobTitle  \
# 0               1  Gutierrez     Molly      F    Burnaby    Baker
# 1               2   Hardwick   Stephen      M  Courtenay    Baker
#
#   DepartmentName StoreLocation Division        Age  LengthService  \
# 0         Bakery       Burnaby   Stores  32.028816       6.018478
# 1         Bakery       Nanaimo   Stores  40.320902       5.532445
#
#    AbsentHours BusinessUnit  new_Gender  new_City  new_Title  new_Dept  \
# 0    36.577306       Stores           0         0          0         0
# 1    30.165072       Stores           1         1          0         0
#
#    new_StoreLoc  new_Division
# 0             0             0
# 1             1             0

# %%
import numpy as np

X = data[['Age', 'LengthService', 'new_Gender', 'new_City', 'new_Title', 'new_Dept',  'new_StoreLoc', 'new_Division']].values
y= data['AbsentHours'].values
X.shape
# Out:
# (8336, 8)

# %%
from sklearn.preprocessing import StandardScaler

X = StandardScaler().fit_transform(X)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.30)
X_train.shape
# Out:
# (5835, 8)

# %%
from sklearn.tree import DecisionTreeRegressor, ExtraTreeRegressor
from sklearn.linear_model import Ridge, Lasso, LinearRegression, ElasticNet, Lars
from sklearn.ensemble import AdaBoostRegressor, GradientBoostingRegressor, ExtraTreesRegressor, RandomForestRegressor
from sklearn.metrics import mean_squared_error


regressors = [DecisionTreeRegressor(), ExtraTreeRegressor(), AdaBoostRegressor(), GradientBoostingRegressor(), ExtraTreesRegressor(), RandomForestRegressor(),
Ridge(), Lasso(), LinearRegression(), ElasticNet(), Lars()]

log_cols=["regressors", "MSE"]
log = pd.DataFrame(columns=log_cols)

for rgr in regressors:
    rgr.fit(X_train, y_train)
    name = rgr.__class__.__name__
    
    print("="*30)
    print(name)
    
    print('****Results****')
    
    train_predictions = rgr.predict(X_test)
    mse = np.sqrt(mean_squared_error(y_test, train_predictions))
    print("RMSE: {}".format(mse))
    
    
    log_entry = pd.DataFrame([[name, mse]], columns=log_cols)
    log = log.append(log_entry)
print(log)
    
print("="*30)
# Out:
# ...
# DecisionTreeRegressor
# ****Results****
# RMSE: 34.95289158221901
# ...
# ExtraTreeRegressor
# ****Results****
# RMSE: 34.69807237020635
# ...
# AdaBoostRegressor
# ****Results****
# RMSE: 27.231725035370918
# ...
# GradientBoostingRegressor
# ****Results****
# RMSE: 24.377771330186903
# ...
# ExtraTreesRegressor
# ****Results****
# RMSE: 26.329241026396108
# ...
# RandomForestRegressor
# ****Results****
# RMSE: 25.67540414642253
# ...
# Ridge
# ****Results****
# RMSE: 26.27153935883014
# ...
# Lasso
# ****Results****
# RMSE: 26.488808181130896
# ...
# LinearRegression
# ****Results****
# RMSE: 26.271570795488884
# ...
# ElasticNet
# ****Results****
# RMSE: 27.089060053973856
# ...
# Lars
# ****Results****
# RMSE: 26.27157079548888
#                   regressors        MSE
# 0      DecisionTreeRegressor  34.952892
# 0         ExtraTreeRegressor  34.698072
# 0          AdaBoostRegressor  27.231725
# 0  GradientBoostingRegressor  24.377771
# 0        ExtraTreesRegressor  26.329241
# 0      RandomForestRegressor  25.675404
# ...

# %%
from sklearn.tree import DecisionTreeRegressor, ExtraTreeRegressor
from sklearn.linear_model import Ridge, Lasso, LinearRegression, ElasticNet, Lars
from sklearn.ensemble import AdaBoostRegressor, GradientBoostingRegressor, ExtraTreesRegressor, RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score


models = [DecisionTreeRegressor(), ExtraTreeRegressor(), AdaBoostRegressor(), 
              GradientBoostingRegressor(), ExtraTreesRegressor(), RandomForestRegressor(),
            Ridge(), Lasso(), LinearRegression(), ElasticNet(), Lars()]

columns=['model', 'mse', 'rmse']
df = pd.DataFrame(columns=columns)

for model in models:
    each_model = model.fit(X_train, y_train)
    each = model.__class__.__name__
    print(each_model)
    
    
    predictions = each_model.predict(X_test)
    print("predictions =", predictions)
    
    
    mse = mean_squared_error(y_test, predictions)
    print("mse =", mse)
    
    rmse = np.sqrt(mse)
    print("rmse =", rmse)
    
    #r2_score = r2_score(y_test, predictions)
    #print("r2_score =", r2_score)
    #print()

    
    dd = pd.DataFrame([[each_model, mse, rmse]], columns=columns)
    df = df.append(dd)

print(df)    


#for rgr in regressors:
#    rgr.fit(X_train, y_train)
#    name = rgr.__class__.__name__
    
#    print("="*30)
#    print(name)
    
#    print('****Results****')
    
#    train_predictions = rgr.predict(X_test)
#    mse = np.sqrt(mean_squared_error(y_test, train_predictions))
#    print("RMSE: {}".format(mse))
    
    
#    log_entry = pd.DataFrame([[name, mse]], columns=log_cols)
#    log = log.append(log_entry)
    
#print("="*30)
# Out:
# DecisionTreeRegressor()
# predictions = [109.7800272   54.59844664   1.30744506 ...  68.15333527  69.54990197
#    0.        ]
# mse = 1219.0509381540685
# rmse = 34.91490996915313
# ExtraTreeRegressor()
# predictions = [ 68.44954833  48.15769642  30.85499852 ...  43.17986724 107.4865556
#    0.        ]
# mse = 1180.3126604303643
# rmse = 34.35567872172466
# AdaBoostRegressor()
# predictions = [81.65850593 70.27400634 34.06494479 ... 74.33910531 84.35118428
#  26.82418499]
# mse = 724.1640992093611
# rmse = 26.910297270921426
# GradientBoostingRegressor()
# predictions = [96.74851936 66.88337477 22.82332553 ... 77.09409342 93.16892823
#   2.448382  ]
# mse = 593.9880384691243
# rmse = 24.371869818894165
# ExtraTreesRegressor()
# predictions = [92.1180878  65.27295526 26.83198238 ... 64.03413893 85.7361251
#   1.90963962]
# mse = 690.5880323006892
# rmse = 26.279041692966835
# RandomForestRegressor()
# predictions = [99.90532575 63.25523365 22.97431804 ... 67.25456318 85.61895979
# ...

# %%
sns.set_color_codes("muted")
sns.barplot(x='MSE', y='modelss', data=log, color="g")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-435-b866ac648a7f> in <module>
#       1 sns.set_color_codes("muted")
# ----> 2 sns.barplot(x='MSE', y='modelss', data=log, color="g")
#
# D:\New folder\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# D:\New folder\lib\site-packages\seaborn\categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3177 ):
#    3178
# -> 3179     plotter = _BarPlotter(x, y, hue, data, order, hue_order,
#    3180                           estimator, ci, n_boot, units, seed,
# ...
